# %% [markdown]
# # Introduction
#
# ### What is DCGAN ?
#
# DCGAN (Deep Convolutional Generative Adversarial Network) is a generative model that utilizes deep convolutional neural networks to generate new data samples, particularly realistic images. It consists of a generator network that takes random noise as input and produces fake images, and a discriminator network that distinguishes between real and fake images. The generator and discriminator are trained simultaneously in an adversarial manner, where the generator aims to deceive the discriminator, while the discriminator aims to accurately classify the real and fake images. DCGAN has found extensive applications in image generation tasks, such as generating lifelike images of faces, objects, and scenes, and has also been extended to other domains like music and text generation
#
# <img src="images/GAN.png" />

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
# Define transformations
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize the data to have mean 0.5 and std 0.5
])


# Load the Fashion-MNIST dataset
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# ...
# 100%|██████████| 26.4M/26.4M [00:16<00:00, 1.65MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 211kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.89MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 5.95MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %% [markdown]
# #### Showing some samples of data

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(train_dataset[i][0].squeeze().numpy(), cmap='gray')
    plt.title(train_dataset.classes[train_dataset[i][1]])
    plt.axis('off')

# %% [markdown]
# # Generator Architecture for Fashion-MNIST
#
# ## Input
# - **Latent Vector `z`**: A vector of size `latent_dim` (default is 100), sampled from a standard normal distribution.
#
# ## Overview
# The Generator progressively upsamples the latent vector into a realistic Fashion-MNIST image using transposed convolutions, batch normalization, and activation functions. This architecture is simple, enabling efficient training and experimentation, and is well-suited for the relatively straightforward structure of the Fashion-MNIST dataset.
#
# ---
#
# ## Architecture Details
#
# ### First Layer
# 1. **Transposed Convolution**:
#    `nn.ConvTranspose2d(latent_dim, 128, kernel_size=7, stride=1, padding=0)`
#    - Transforms the latent vector into a 7x7 spatial dimension with 128 feature maps to initiate upsampling.
#
# 2. **Batch Normalization**:
#    `nn.BatchNorm2d(128)`
#    - Stabilizes training by normalizing the outputs, preventing internal covariate shift and accelerating convergence.
#
# 3. **Activation**:
#    `nn.ReLU(True)`
#    - Applies the Rectified Linear Unit (ReLU) activation function, introducing non-linearity for learning complex patterns.
#
# ---
#
# ### Second Layer
# 1. **Transposed Convolution**:
#    `nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1)`
#    - Upsamples the spatial resolution to 14x14 and reduces the feature maps to 64.
#
# 2. **Batch Normalization**:
#    `nn.BatchNorm2d(64)`
#    - Normalizes the outputs for stabilized training.
#
# 3. **Activation**:
#    `nn.ReLU(True)`
#    - Applies the ReLU activation function for non-linearity.
#
# ---
#
# ### Third Layer
# 1. **Transposed Convolution**:
#    `nn.ConvTranspose2d(64, 1, kernel_size=4, stride=2, padding=1)`
#    - Upsamples the spatial resolution to the target size of 28x28, matching Fashion-MNIST dimensions. Outputs a single channel for the grayscale image.
#
# 2. **Activation**:
#    `nn.Tanh()`
#    - Normalizes the pixel values of the generated image to the range [-1, 1], ensuring compatibility with the expected Fashion-MNIST format.

# %%
import torch.nn as nn

class Generator(nn.Module):
    def __init__(self, latent_dim=100):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, 128, kernel_size=7, stride=1, padding=0),
            nn.BatchNorm2d(128),
            nn.ReLU(True),

            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),

            nn.ConvTranspose2d(64, 1, kernel_size=4, stride=2, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z)

# %% [markdown]
# ## Discriminator
# **Input**: A single-channel 28x28 image (e.g., Fashion-MNIST sample).
#
# **Architecture**:
# 1. **First Layer**:
#    - `nn.Conv2d(1, 64, kernel_size=4, stride=2, padding=1)`: Downsamples to 14x14 while extracting 64 features.
#    - `nn.LeakyReLU(0.2, inplace=True)`: Provides non-linearity and avoids dying gradients.
#
# 2. **Second Layer**:
#    - Further downsamples to 7x7 with 128 features.
#    - `nn.BatchNorm2d(128)`: Stabilizes learning.
#    - `nn.LeakyReLU(0.2, inplace=True)`: Introduces non-linearity.
#
# 3. **Fully Connected Layer**:
#    - Flattens the 7x7x128 tensor and applies `nn.Linear(128 * 7 * 7, 1)` to produce a single output (real or fake).
#    - `nn.Sigmoid()`: Outputs a probability score between 0 and 1.

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Flatten(),
            nn.Linear(128 * 7 * 7, 1),
            nn.Sigmoid()
        )

    def forward(self, img):
        return self.model(img)

# %%
latent_dim = 100
generator = Generator(latent_dim)
discriminator = Discriminator()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
generator.to(device)
discriminator.to(device)
device
# Out:
# device(type='cuda')

# %%
criterion = nn.BCELoss()
d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002)
g_optimizer = optim.Adam(generator.parameters(), lr=0.0002)

# %% [markdown]
# ### adversarial loss used to train a GAN.
# <img src="DC-GAN-LOSS.png" />
# The discriminator minimizes LD, trying to correctly classify real vs. fake samples.
# The generator minimizes LG, aiming to generate samples that the discriminator classifies as real.

# %%
def train_discriminator(discriminator, images, real_labels, fake_images, fake_labels):
    discriminator.zero_grad()
    # here we get the first part of the formula for loss
    outputs = discriminator(images)
    real_loss = criterion(outputs, real_labels)
    real_score = outputs

    # here is the second part
    outputs = discriminator(fake_images)
    fake_loss = criterion(outputs, fake_labels)
    fake_score = outputs

    d_loss = real_loss + fake_loss
    d_loss.backward()
    d_optimizer.step()
    return d_loss, real_score, fake_score

def train_generator(generator, discriminator_outputs, real_labels):
    generator.zero_grad()
    g_loss = criterion(discriminator_outputs, real_labels)
    g_loss.backward()
    g_optimizer.step()
    return g_loss

# %%
num_epochs = 100
num_batches = len(train_loader)
latent_dim = 100
fixed_noise = torch.randn(9, latent_dim, 1, 1, device=device)

# %%
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(train_loader):
        real_labels = torch.ones(images.size(0), 1, device=device)
        fake_labels = torch.zeros(images.size(0), 1, device=device)
        images = images.to(device)

        # Train the discriminator
        z = torch.randn(images.size(0), latent_dim, 1, 1, device=device)
        fake_images = generator(z)
        d_loss, real_score, fake_score = train_discriminator(discriminator, images, real_labels, fake_images, fake_labels)

        # Train the generator
        z = torch.randn(images.size(0), latent_dim, 1, 1, device=device)
        fake_images = generator(z)
        outputs = discriminator(fake_images)
        g_loss = train_generator(generator, outputs, real_labels)

        if (i + 1) % 200 == 0:
            print(f'Epoch [{epoch}/{num_epochs}], Step [{i + 1}/{num_batches}], d_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}, D(x): {real_score.mean().item():.2f}, D(G(z)): {fake_score.mean().item():.2f}')

    generator.eval()
    fake_images = generator(fixed_noise)
    generator.train()

    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(fake_images[i].squeeze().detach().cpu().numpy(), cmap='gray')
        plt.axis('off')
    plt.show()
# Out:
# Epoch [0/100], Step [200/938], d_loss: 0.0155, g_loss: 5.5104, D(x): 1.00, D(G(z)): 0.01
# Epoch [0/100], Step [400/938], d_loss: 0.0074, g_loss: 6.2652, D(x): 1.00, D(G(z)): 0.00
# Epoch [0/100], Step [600/938], d_loss: 0.0015, g_loss: 7.6986, D(x): 1.00, D(G(z)): 0.00
# Epoch [0/100], Step [800/938], d_loss: 0.0853, g_loss: 4.3269, D(x): 0.99, D(G(z)): 0.07
# Epoch [1/100], Step [200/938], d_loss: 0.3402, g_loss: 2.7020, D(x): 0.89, D(G(z)): 0.17
# Epoch [1/100], Step [400/938], d_loss: 0.2378, g_loss: 2.9237, D(x): 0.92, D(G(z)): 0.12
# Epoch [1/100], Step [600/938], d_loss: 0.4126, g_loss: 2.8904, D(x): 0.81, D(G(z)): 0.14
# Epoch [1/100], Step [800/938], d_loss: 0.2838, g_loss: 2.1684, D(x): 0.89, D(G(z)): 0.14
# Epoch [2/100], Step [200/938], d_loss: 0.2321, g_loss: 2.3129, D(x): 0.95, D(G(z)): 0.15
# Epoch [2/100], Step [400/938], d_loss: 0.3001, g_loss: 3.4108, D(x): 0.84, D(G(z)): 0.07
# ...

# %% [markdown]
# ## Weight Initialization
# the recommended initialization method is normal initialization with a mean of 0 and a standard deviation of 0.02.
#
# we are going to rerun the sections above to check the effect of weight initialization in our training.

# %%
def weights_init(m):
    if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
        nn.init.normal_(m.weight.data, mean=0.0, std=0.02)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0)

# %%
num_epochs = 100
latent_dim = 100

generator = Generator()
discriminator = Discriminator()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

generator.to(device)
discriminator.to(device)

generator.apply(weights_init)
discriminator.apply(weights_init)

criterion = nn.BCELoss()
d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002)
g_optimizer = optim.Adam(generator.parameters(), lr=0.0002)

num_batches = len(train_loader)
fixed_noise = torch.randn(9, latent_dim, 1, 1, device=device)

# %%
import IPython.display as display

# %%
# !pip install tensorboard
display.clear_output()

# %%
# !tensorboard --logdir=/content/dcgan
# Out:
# 2025-01-02 12:20:14.037780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-02 12:20:14.069241: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-02 12:20:14.079125: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-02 12:20:14.100589: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from torch.utils.tensorboard import SummaryWriter
import torchvision

writer = SummaryWriter("runs/dcgan")

# %%
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(train_loader):
        real_labels = torch.ones(images.size(0), 1, device=device)
        fake_labels = torch.zeros(images.size(0), 1, device=device)
        images = images.to(device)

        # Train the discriminator
        z = torch.randn(images.size(0), latent_dim, 1, 1, device=device)
        fake_images = generator(z)
        d_loss, real_score, fake_score = train_discriminator(discriminator, images, real_labels, fake_images, fake_labels)

        # Train the generator
        z = torch.randn(images.size(0), latent_dim, 1, 1, device=device)
        fake_images = generator(z)
        outputs = discriminator(fake_images)
        g_loss = train_generator(generator, outputs, real_labels)

        # Log losses
        writer.add_scalar("Loss/Discriminator", d_loss.item(), epoch * num_batches + i)
        writer.add_scalar("Loss/Generator", g_loss.item(), epoch * num_batches + i)

        if (i + 1) % 200 == 0:
            print(f'Epoch [{epoch}/{num_epochs}], Step [{i + 1}/{num_batches}], d_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}, D(x): {real_score.mean().item():.2f}, D(G(z)): {fake_score.mean().item():.2f}')

    # Visualize generator output
    generator.eval()
    fake_images = generator(fixed_noise)
    generator.train()

    grid = torchvision.utils.make_grid(fake_images, normalize=True)
    writer.add_image("Generated Images", grid, global_step=epoch)

writer.close()
# Out:
# Epoch [0/100], Step [200/938], d_loss: 0.0303, g_loss: 4.5822, D(x): 0.98, D(G(z)): 0.01
# Epoch [0/100], Step [400/938], d_loss: 0.0159, g_loss: 5.3668, D(x): 0.99, D(G(z)): 0.01
# Epoch [0/100], Step [600/938], d_loss: 0.0771, g_loss: 4.0851, D(x): 0.97, D(G(z)): 0.05
# Epoch [0/100], Step [800/938], d_loss: 0.4887, g_loss: 3.0250, D(x): 0.78, D(G(z)): 0.16
# Epoch [1/100], Step [200/938], d_loss: 0.3736, g_loss: 2.4879, D(x): 0.82, D(G(z)): 0.13
# Epoch [1/100], Step [400/938], d_loss: 0.3646, g_loss: 2.2675, D(x): 0.87, D(G(z)): 0.18
# Epoch [1/100], Step [600/938], d_loss: 0.3712, g_loss: 2.5670, D(x): 0.85, D(G(z)): 0.16
# Epoch [1/100], Step [800/938], d_loss: 0.3240, g_loss: 2.3684, D(x): 0.82, D(G(z)): 0.09
# Epoch [2/100], Step [200/938], d_loss: 0.2408, g_loss: 3.1056, D(x): 0.86, D(G(z)): 0.07
# Epoch [2/100], Step [400/938], d_loss: 0.3537, g_loss: 2.4301, D(x): 0.84, D(G(z)): 0.13
# ...

# %%
# save the model completly
torch.save(generator.state_dict(), 'generator.pth')
torch.save(discriminator.state_dict(), 'discriminator.pth')

# %%
fake_images = generator(fixed_noise)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(fake_images[i].squeeze().detach().cpu().numpy(), cmap='gray')

# %%
fixed_noise2 = torch.randn(25, latent_dim, 1, 1, device=device)

generator.eval()
fake_images = generator(fixed_noise2)
generator.train()

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(fake_images[i].squeeze().detach().cpu().numpy(), cmap='gray')

# %% [markdown]
# ### Challenges in the project:
#
# 1. **Training Instability**
#    One of the main problems I face is the instability during training. Sometimes, the discriminator becomes too strong, leading to issues like mode collapse, where the generator repeatedly produces similar outputs rather than diverse ones.
#
# 2. **Hyperparameter Tuning**
#    Selecting the right hyperparameters, such as the learning rate, batch size, and optimizer settings, requires a lot of trial and error. The process is time-consuming, and small changes can significantly affect the results.
#
# 3. **Vanishing or Exploding Gradients**
#    I noticed that during training, gradients can sometimes vanish or explode, especially when using **deeper networks**. This makes it difficult for the model to learn effectively.

# %% [markdown]
# ## Resources:
# 1. https://www.youtube.com/watch?v=mfI5-s3-Bjk&t=1s
# 2. https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html
# 3. https://medium.com/@manoharmanok/implementing-dcgan-in-pytorch-using-the-celeba-dataset-a-comprehensive-guide-660e6e8e29d2
# 4. https://brsoff.github.io/tutorials/beginner/dcgan_faces_tutorial.html
